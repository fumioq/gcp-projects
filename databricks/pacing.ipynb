# %% [markdown]
# # Load data to Delta Lake from GCS with EXTERNAL TABLE and ETL the data.
#
# This notebook shows you how to create a Delta Lake from by using `CREATE TABLE` to load data from Google Cloud Storage (GCS) as External Tables.

# %% [markdown]
# ## Creating our database and tables

# %%
# %sql
CREATE DATABASE test_database

# %%
# %sql
CREATE TABLE test_database.planned_data
USING csv
OPTIONS (path "gs://databricks_data_example/table_planned.csv", header "true", inferSchema "true", delimiter ",")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE test_database.googleads_data
USING csv
OPTIONS (path "gs://databricks_data_example/table_googleads_ads.csv", header "true", inferSchema "true", delimiter ",")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE test_database.facebookads_data
USING csv
OPTIONS (path "gs://databricks_data_example/table_fbmarketing_platform.csv", header "true", inferSchema "true", delimiter ",")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE test_database.linkedinads_data
USING csv
OPTIONS (path "gs://databricks_data_example/table_linkedinads_ads.csv", header "true", inferSchema "true", delimiter ",")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Data ETL
#
# Now that our tables are extractiong data from GCP Google Storage, we can extract and process them.

# %%
import pandas as pd
from pyspark.sql.functions import lit, col, when

# %%
df_planned = spark.read.table("test_database.planned_data")
df_facebook = spark.read.table('test_database.facebookads_data')
df_linkedin = spark.read.table('test_database.linkedinads_data')
df_google = spark.read.table('test_database.googleads_data')

# %% [markdown]
# ### Renaming fields
#
# We're going to union all 4 tables into one DF, so let's make sure that their fields have the same name.

# %%
# Correcting column names of planned table
new_columns = [
            'publisher',
            'date',
            'campaign_name',
            'spend_planned',
            'impressions_planned',
            'clicks_planned',
            'video_views_planned',
            'video_views_100p_planned',
            'leads_planned',
            'sessions_planned',
            'goal1_planned',
            'goal2_planned',
      ]

df_planned = df_planned.toDF(*new_columns)
df_planned = df_planned.drop('sessions_planned', 'goal1_planned', 'goal2_planned')

# %%
# Correcting column names of facebook table
new_columns = [
            'publisher',
            'account_id',
            'date',
            'campaign_name',
            'adset_name',
            'ad_name',
            'spend',
            'impressions',
            'clicks',
            'device',
            'video_views',
            'video_views_25p',
            'video_views_50p',
            'video_views_75p',
            'video_views_100p',
            'reactions',
            'comments',
            'shares',
            'engagements',
            'leads',
            'video_views_95p',
      ]

df_facebook = df_facebook.toDF(*new_columns)

# %%
# Correcting column names of googleads table
new_columns = [
            'account_id',
            'date',
            'campaign_name',
            'adset_name',
            'ad_name',
            'device',
            'segments_adNetworkType',
            'publisher',
            'spend',
            'impressions',
            'clicks',
            'active_views_impressions',
            'video_views',
            'video_views_25p',
            'video_views_50p',
            'video_views_75p',
            'video_views_100p',
            'engagements',
      ]

df_google = df_google.toDF(*new_columns)
df_google = df_google.withColumn('spend', col('spend') / 1000000)
df_google = df_google.withColumn('publisher', lit('googleads'))

# %%
# Correcting column names of googleads table
new_columns = [
            'account_id',
            'date',
            'campaign_name',
            'spend',
            'impressions',
            'clicks',
            'video_views',
            'video_views_25p',
            'video_views_50p',
            'video_views_75p',
            'video_views_100p',
            'reactions',
            'comments',
            'shares',
      ]

df_linkedin = df_linkedin.toDF(*new_columns)
df_linkedin = df_linkedin.withColumn('publisher', lit('linkedinads'))

# %% [markdown]
# ### Unite all platforms data

# %%
all_media_data = df_facebook.unionByName(df_linkedin, allowMissingColumns=True).unionByName(df_google, allowMissingColumns=True)

all_media_data = all_media_data.drop('device', 'adset_name', 'ad_name', 'device', 'video_views_25p', 'video_views_50p', 'video_views_75p', 'video_views_95p', 'reactions', 'comments', 'shares', 'engagements', 'active_views_impressions', 'segments_adNetworkType')

# %% [markdown]
# ### Unite with planned data

# %%
consolidated_data = all_media_data.unionByName(df_planned, allowMissingColumns=True)

# %%
display(consolidated_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publisher</th><th>account_id</th><th>date</th><th>campaign_name</th><th>spend</th><th>impressions</th><th>clicks</th><th>video_views</th><th>video_views_100p</th><th>leads</th><th>spend_planned</th><th>impressions_planned</th><th>clicks_planned</th><th>video_views_planned</th><th>video_views_100p_planned</th><th>leads_planned</th></tr></thead><tbody><tr><td>facebook</td><td>123456789101112</td><td>2022-01-01</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1872.0</td><td>468000.0</td><td>23400.0</td><td>28080.0</td><td>4492.8</td><td>898.56</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-02</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1853.28</td><td>468000.0</td><td>23166.0</td><td>28360.8</td><td>4447.872</td><td>907.5456</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-03</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1834.7472</td><td>472680.0</td><td>22934.34</td><td>28077.192</td><td>4492.35072</td><td>907.5456</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-04</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1853.094672</td><td>477406.8</td><td>22934.34</td><td>28077.192</td><td>4447.427213</td><td>907.5456</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-05</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1853.094672</td><td>477406.8</td><td>22704.9966</td><td>28357.96392</td><td>4402.952941</td><td>898.470144</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-06</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1834.563725</td><td>482180.868</td><td>22704.9966</td><td>28641.54356</td><td>4358.923411</td><td>889.4854426</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-07</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1852.909363</td><td>477359.0593</td><td>22704.9966</td><td>28641.54356</td><td>4358.923411</td><td>898.380297</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-08</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1852.909363</td><td>482132.6499</td><td>22932.04657</td><td>28355.12812</td><td>4315.334177</td><td>889.396494</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-09</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1852.909363</td><td>482132.6499</td><td>23161.36703</td><td>28071.57684</td><td>4272.180835</td><td>898.290459</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-10</td><td>agency3_customer9_campaign-type_facebookads_campaign-objective_fiscal-year</td><td>1852.909363</td><td>482132.6499</td><td>22929.75336</td><td>28071.57684</td><td>4314.902644</td><td>898.290459</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>facebook</td><td>123456789101112</td><td>2022-01-11</td><td>agency3_customer9_campaign-type_facebookads_c ...

# %% [markdown]
# ### Data cleansing
#
# Let's make sure that our metrics have no NA in their values

# %%
fillna_parameters = {
          'spend' : 0,
          'impressions' : 0,
          'clicks' : 0,
          'video_views' : 0,
          'video_views_100p' : 0,
          'leads' : 0,
          'spend_planned' : 0,
          'impressions_planned' : 0,
          'clicks_planned' : 0,
          'video_views_planned' : 0,
          'video_views_100p_planned' : 0,
          'leads_planned' : 0
          }
consolidated_data = consolidated_data.fillna(fillna_parameters)

# %% [markdown]
# ### Data Aggregation
#
# Now that we have all metrics in order, we can aggregate them and make our Pacing visualization.

# %%
aggregated_data = consolidated_data.groupBy('publisher').agg({'spend': 'sum', 'spend_planned' : 'sum', 'clicks': 'sum', 'clicks_planned' : 'sum', 'video_views': 'sum', 'video_views_planned' : 'sum'})
aggregated_data = aggregated_data.withColumn('investment_difference', when(col('sum(spend_planned)') - col('sum(spend)') < 0, 0).when(col('sum(spend_planned)') - col('sum(spend)') >= 0, col('sum(spend_planned)') - col('sum(spend)')))
aggregated_data = aggregated_data.withColumn('clicks_difference', when(col('sum(spend_planned)') - col('sum(spend)') < 0, 0).when(col('sum(spend_planned)') - col('sum(spend)') >= 0, col('sum(spend_planned)') - col('sum(spend)')))
aggregated_data = aggregated_data.withColumn('video_views_difference', when(col('sum(spend_planned)') - col('sum(spend)') < 0, 0).when(col('sum(spend_planned)') - col('sum(spend)') >= 0, col('sum(spend_planned)') - col('sum(spend)')))
display(aggregated_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publisher</th><th>sum(spend)</th><th>sum(video_views)</th><th>sum(clicks_planned)</th><th>sum(spend_planned)</th><th>sum(video_views_planned)</th><th>sum(clicks)</th><th>investment_difference</th><th>clicks_difference</th><th>video_views_difference</th></tr></thead><tbody><tr><td>facebook</td><td>617551.9403330008</td><td>9780169.541779993</td><td>7675297.961000004</td><td>646902.9930000012</td><td>2.2689993335000012E7</td><td>7309807.60466</td><td>29351.05266700033</td><td>29351.05266700033</td><td>29351.05266700033</td></tr><tr><td>linkedinads</td><td>367907.1102572001</td><td>3358468.6046829973</td><td>75423.55099999995</td><td>374265.2539999999</td><td>3358468.596999999</td><td>71831.94895129999</td><td>6358.143742799817</td><td>6358.143742799817</td><td>6358.143742799817</td></tr><tr><td>googleads</td><td>1630001.4633670012</td><td>3.758758349546998E7</td><td>2.2033801655999992E7</td><td>1662601.493</td><td>3.7587583494000025E7</td><td>2.098457299752E7</td><td>32600.029632998863</td><td>32600.029632998863</td><td>32600.029632998863</td></tr></tbody></table></div>
# Output can only be rendered in Databricks
# Output can only be rendered in Databricks
# Output can only be rendered in Databricks
# Output can only be rendered in Databricks
